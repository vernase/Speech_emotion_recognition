# %%
import pandas as pd
import numpy as np


import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score

from sklearn.metrics import accuracy_score, confusion_matrix
import time

#needed for pipeline
import os
import sys

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
features = pd.read_csv("features/berlin_features.csv")
features
# Out:
#                audio_name  actor text  emotion  \
# 0    data/wav/03a01Fa.wav      3  a01    happy
# 1    data/wav/03a01Nc.wav      3  a01  neutral
# 2    data/wav/03a01Wa.wav      3  a01    anger
# 3    data/wav/03a02Fc.wav      3  a02    happy
# 4    data/wav/03a02Nc.wav      3  a02  neutral
# 5    data/wav/03a02Ta.wav      3  a02  sadness
# 6    data/wav/03a02Wb.wav      3  a02    anger
# 7    data/wav/03a02Wc.wav      3  a02    anger
# 8    data/wav/03a04Ad.wav      3  a04  anxiety
# 9    data/wav/03a04Fd.wav      3  a04    happy
# 10   data/wav/03a04Lc.wav      3  a04  boredom
# 11   data/wav/03a04Nc.wav      3  a04  neutral
# 12   data/wav/03a04Ta.wav      3  a04  sadness
# 13   data/wav/03a04Wc.wav      3  a04    anger
# 14   data/wav/03a05Aa.wav      3  a05  anxiety
# 15   data/wav/03a05Fc.wav      3  a05    happy
# 16   data/wav/03a05Nd.wav      3  a05  neutral
# 17   data/wav/03a05Tc.wav      3  a05  sadness
# 18   data/wav/03a05Wa.wav      3  a05    anger
# 19   data/wav/03a05Wb.wav      3  a05    anger
# 20   data/wav/03a07Fa.wav      3  a07    happy
# 21   data/wav/03a07Fb.wav      3  a07    happy
# 22   data/wav/03a07La.wav      3  a07  boredom
# 23   data/wav/03a07Nc.wav      3  a07  neutral
# 24   data/wav/03a07Wc.wav      3  a07    anger
# 25   data/wav/03b01Fa.wav      3  b01    happy
# 26   data/wav/03b01Lb.wav      3  b01  boredom
# 27   data/wav/03b01Nb.wav      3  b01  neutral
# 28   data/wav/03b01Td.wav      3  b01  sadness
# 29   data/wav/03b01Wa.wav      3  b01    anger
# ..                    ...    ...  ...      ...
# 505  data/wav/16b01Tb.wav     16  b01  sadness
# 506  data/wav/16b01Wa.wav     16  b01    anger
# 507  data/wav/16b01Wb.wav     16  b01    anger
# 508  data/wav/16b02Aa.wav     16  b02  anxiety
# 509  data/wav/16b02Eb.wav     16  b02  disgust
# 510  data/wav/16b02Fd.wav     16  b02    happy
# 511  data/wav/16b02Lb.wav     16  b02  boredom
# 512  data/wav/16b02Wb.wav     16  b02    anger
# 513  data/wav/16b03Ad.wav     16  b03  anxiety
# 514  data/wav/16b03Ea.wav     16  b03  disgust
# 515  data/wav/16b03Fa.wav     16  b03    happy
# 516  data/wav/16b03Fd.wav     16  b03    happy
# 517  data/wav/16b03La.wav     16  b03  boredom
# 518  data/wav/16b03Nb.wav     16  b03  neutral
# 519  data/wav/16b03Ta.wav     16  b03  sadness
# 520  data/wav/16b03Wb.wav     16  b03    anger
# 521  data/wav/16b09Ab.wav     16  b09  anxiety
# 522  data/wav/16b09Eb.wav     16  b09  disgust
# 523  data/wav/16b09Fb.wav     16  b09    happy
# 524  data/wav/16b09La.wav     16  b09  boredom
# 525  data/wav/16b09Lb.wav     16  b09  boredom
# 526  data/wav/16b09Wb.wav     16  b09    anger
# 527  data/wav/16b10Aa.wav     16  b10  anxiety
# 7                        13.692046  0.323012
# 8                        13.057375  0.210132
# 9                        13.302316  0.450810
# 10                       13.708095  0.248071
# 11                       13.631927  0.246992
# 12                       13.451034  0.283360
# 13                       12.584669  0.285765
# 14                       12.615749  0.214614
# 15                       13.273627  0.305199
# 16                       13.292975  0.339287
# 17                       13.175301  0.310686
# 18                       13.211404  0.284881
# 19                       12.648295  0.305351
# 20                       13.334790  0.212350
# 21                       13.703880  0.122316
# 22                       13.389675  0.109395
# 23                       12.895386  0.184336
# 24                       13.319966  0.184475
# 25                       12.975172  0.195439
# 26                       13.150062  0.236524
# 27                       13.323662  0.255897
# 28                       12.874449  0.362953
# 29                       13.398677  0.222596
# ..                             ...       ...
# 505                      13.297595  0.429761
# 506                      13.440117  0.198806
# 507                      13.362426  0.248080
# 508                      12.770622  0.322209
# 509                      12.474102  0.163187
# 510                      13.082450  0.157075
# 511                      13.282705  0.171125
# 512                      12.709236  0.255421
# 513                      13.473825  0.141301
# 514                      13.082710  0.279033
# 515                      12.542897  0.238149
# 516                      12.955187  0.186132
# 517                      12.989746  0.130645
# 518                      12.902018  0.143122
# 519                      13.076815  0.314010
# 520                      13.425031  0.276851
# 521                      13.244579  0.162852
# 522                      13.459828  0.300728
# 523                      13.133614  0.394832
# 524                      13.097956  0.144126
# 525                      13.223722  0.193486
# 526                      12.881946  0.374526
# 527                      12.062118  0.261732
# 528                      13.495269  0.177953
# 529                      11.617725  0.249388
# 530                      13.517172  0.170360
# 531                      12.119882  0.264363
# 532                      12.694482  0.268198
# 533                      12.512841  0.384742
# 534                      13.116568  0.226524
#
# [535 rows x 32 columns]

# %%
x=features.drop(['audio_name','actor','text','emotion','sound'], axis=1)
y =features["emotion"].values

# %%
#数据标准化
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
#x = preprocessing.scale(x)
scaler = StandardScaler()
x = scaler.fit_transform(x)

#from sklearn.preprocessing import MinMaxScaler
#minmax=MinMaxScaler(feature_range=(0.0,1.0))
#x=minmax.fit_transform(x)
x
# Out:
# array([[-0.85800031, -0.2536377 ,  0.96938636, ..., -1.95270469,
#          0.40002035,  1.30844428],
#        [-1.13739313,  0.18871181,  1.90857584, ..., -0.80367655,
#          1.3235422 ,  2.30999017],
#        [-0.8778961 , -0.6018036 , -0.00966082, ..., -1.63685489,
#          1.27351311,  1.22245512],
#        ...,
#        [ 1.1239729 ,  0.26740816,  0.05927703, ...,  1.68663397,
#         -1.29714239,  0.32887188],
#        [-0.35579903, -2.45643571,  1.44348649, ..., -0.34819328,
#         -1.78768358,  1.39921622],
#        [-0.2502966 , -1.38015542, -0.93807446, ..., -0.15785797,
#         -0.15725105, -0.05386058]])

# %%
# PCA降维  效果不好
#from sklearn.decomposition import PCA
##加载PCA模型并训练、降维
#model_pca = PCA(n_components=5) #n_components设置降维后的维度
#X_pca = model_pca.fit(x).transform(x)
#print(x.shape)
#print(X_pca.shape)
#print(X_pca)

# %%
# PCA降维的数据划分
#x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X_pca, y, test_size=0.20, random_state=42)

# %%
# 划分数据集
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.20, random_state=42)

# %%
#LDA降维
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=5)
lda.fit(x_train,y_train)
print(lda.score(x_test,y_test))#score是指分类的正确率
# Out:
# 0.7757009345794392

# %%
# SVM
clf_svc = sklearn.svm.SVC(gamma='auto',kernel = 'linear')
clf_svc.fit(x_train, y_train)
scores = cross_val_score(clf_svc, x_test, y_test,cv=5, scoring = 'accuracy')
acc = accuracy_score(y_test,clf_svc.predict(x_test))
print(acc)
#print(np.mean(scores))
# Out:
# 0.6728971962616822

# %%
# 网格搜索优化
from sklearn.model_selection import GridSearchCV
from sklearn import svm
#构建参数网格
parameters =[{'kernel': ['linear','rbf'], 'C': [1, 2, 4, 8,10,100,1000]}]

clf_svc1=GridSearchCV(estimator=svm.SVC(),param_grid=parameters,cv=5,n_jobs=-1,scoring='accuracy')
clf_svc1.fit(x_train,y_train)
# Out:
# C:\Users\61446\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\61446\AppData\Roaming\Python\Python36\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid=[{'C': [1, 2, 4, 8, 10, 100, 1000],
#                           'kernel': ['linear', 'rbf']}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print("Best parameters set found on development set:")
print()
print(clf_svc1.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf_svc1.cv_results_['mean_test_score']
stds = clf_svc1.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf_svc1.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
print()
# Out:
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.668 (+/-0.043) for {'C': 1, 'kernel': 'linear'}
# 0.652 (+/-0.046) for {'C': 1, 'kernel': 'rbf'}
# 0.661 (+/-0.038) for {'C': 2, 'kernel': 'linear'}
# 0.661 (+/-0.038) for {'C': 2, 'kernel': 'rbf'}
# 0.636 (+/-0.016) for {'C': 4, 'kernel': 'linear'}
# 0.668 (+/-0.015) for {'C': 4, 'kernel': 'rbf'}
# 0.624 (+/-0.020) for {'C': 8, 'kernel': 'linear'}
# 0.666 (+/-0.027) for {'C': 8, 'kernel': 'rbf'}
# 0.631 (+/-0.030) for {'C': 10, 'kernel': 'linear'}
# 0.671 (+/-0.033) for {'C': 10, 'kernel': 'rbf'}
# 0.624 (+/-0.037) for {'C': 100, 'kernel': 'linear'}
# 0.678 (+/-0.056) for {'C': 100, 'kernel': 'rbf'}
# 0.629 (+/-0.030) for {'C': 1000, 'kernel': 'linear'}
# 0.678 (+/-0.056) for {'C': 1000, 'kernel': 'rbf'}

# %%
#scores = cross_val_score(clf_svc1, x_test, y_test, cv=5, scoring = 'accuracy')
#print(np.mean(scores))
acc = accuracy_score(y_test,clf_svc.predict(x_test))
print(acc)
# Out:
# 0.6728971962616822

# %%
cm = confusion_matrix(clf_svc.predict(x_test), y_test)
print(confusion_matrix(clf_svc.predict(x_test), y_test))
# Out:
# [[12  2  1  1  5  0  0]
#  [ 0 10  0  2  1  3  0]
#  [ 0  0 14  0  0  2  0]
#  [ 0  0  0  7  1  0  0]
#  [ 6  2  1  2 10  1  0]
#  [ 0  0  1  0  1 10  0]
#  [ 0  0  3  0  0  0  9]]

# %%
sns.heatmap(cm,cmap="OrRd")
plt.tight_layout()
plt.show()

plt.savefig("results/confusion_matrix.png",dpi = 500)

# %%
from sklearn.metrics import classification_report

print(classification_report( y_test,clf_svc.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.57      0.67      0.62        18
#      anxiety       0.62      0.71      0.67        14
#      boredom       0.88      0.70      0.78        20
#      disgust       0.88      0.58      0.70        12
#        happy       0.45      0.56      0.50        18
#      neutral       0.83      0.62      0.71        16
#      sadness       0.75      1.00      0.86         9
#
#     accuracy                           0.67       107
#    macro avg       0.71      0.69      0.69       107
# weighted avg       0.70      0.67      0.68       107
